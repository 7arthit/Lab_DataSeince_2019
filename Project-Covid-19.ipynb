# %% [markdown]
# โหลดข้อมูล

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/DS/dataCovid/confirmed-cases-since-120864.csv')
df
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0        816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1        816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2        816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3        816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4        816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 213287  1030277     21/8/2021     20/8/2021   ชาย  47.0   ปี    Thailand
# 213288  1030278     21/8/2021     20/8/2021   ชาย  79.0   ปี    Thailand
# 213289  1030279     21/8/2021     20/8/2021   ชาย  29.0   ปี    Thailand
# 213290  1030280     21/8/2021     20/8/2021   ชาย  31.0   ปี    Thailand
# 213291  1030281     21/8/2021     20/8/2021   ชาย  46.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# ...

# %%
df.head(5)
# Out:
#       No. announce_date   sex   age province_of_isolation  \
# 0  816990     12/8/2021   ชาย   7.0              เชียงราย
# 1  816991     12/8/2021   ชาย   1.0              เชียงราย
# 2  816992     12/8/2021   ชาย  35.0              เชียงราย
# 3  816993     12/8/2021  หญิง  33.0              เชียงราย
# 4  816994     12/8/2021  หญิง  14.0              เชียงราย
#
#                                           risk
# 0                                        อื่นๆ
# 1                                        อื่นๆ
# 2                                        อื่นๆ
# 3                                        อื่นๆ
# 4  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้

# %% [markdown]
# เลือกข้อมูล 5 คอลัมม์

# %%
df = df[['No.', 'announce_date', 'sex', 'age', 'province_of_isolation', 'risk']]
df
# Out:
#             No. announce_date   sex   age province_of_isolation  \
# 0        816990     12/8/2021   ชาย   7.0              เชียงราย
# 1        816991     12/8/2021   ชาย   1.0              เชียงราย
# 2        816992     12/8/2021   ชาย  35.0              เชียงราย
# 3        816993     12/8/2021  หญิง  33.0              เชียงราย
# 4        816994     12/8/2021  หญิง  14.0              เชียงราย
# ...         ...           ...   ...   ...                   ...
# 213287  1030277     21/8/2021   ชาย  47.0         กรุงเทพมหานคร
# 213288  1030278     21/8/2021   ชาย  79.0         กรุงเทพมหานคร
# 213289  1030279     21/8/2021   ชาย  29.0         กรุงเทพมหานคร
# 213290  1030280     21/8/2021   ชาย  31.0         กรุงเทพมหานคร
# 213291  1030281     21/8/2021   ชาย  46.0                ชลบุรี
#
#                                                risk
# 0                                             อื่นๆ
# 1                                             อื่นๆ
# ...

# %% [markdown]
# 1. ความเสี่ยงในการเป็นผู้ติดเชื่อโควิดคืออะไรบ้าง?

# %%
df['risk'].value_counts()
# Out:
# สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้                                       88413
# อื่นๆ                                                                             52893
# การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน                                  29868
# อยู่ระหว่างการสอบสวน                                                              25537
# ระบุไม่ได้                                                                         5531
# สถานที่ทำงาน                                                                       3918
# ทัณฑสถาน/เรือนจำ                                                                   3164
# ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว                                      2191
# บุคลากรด้านการแพทย์และสาธารณสุข                                                     897
# อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น      373
# ตรวจก่อนทำหัตถการ                                                                   238
# ...

# %% [markdown]
# 2. ค่าสถิติของอายุผู้ติดเชื้อโควิด?

# %%
df.describe()
# Out:
#                 No.            age
# count  2.132920e+05  198386.000000
# mean   9.236355e+05      36.174134
# std    6.157224e+04      17.732531
# min    8.169900e+05       1.000000
# 25%    8.703128e+05      24.000000
# 50%    9.236355e+05      35.000000
# 75%    9.769582e+05      48.000000
# max    1.030281e+06     119.000000

# %% [markdown]
# 3. ช่วงอายุของคนติดเชื้อโควิด?

# %%
df['age'].hist()

# %%
df['age'].hist(bins=[0, 20, 40, 60, 80, 100, 120])

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
plt.style.use('ggplot')
plt.rcParams['font.family'] = 'sans-serif'

# %% [markdown]
# 4. จังหวัดที่เราอยู่ วันนี้มีผู้ติดเชื้อเท่าไหร่ แยกตามเพศ?

# %%
df[df['province_of_isolation'] == 'มหาสารคาม']
# Out:
#             No. announce_date   sex   age province_of_isolation  \
# 11830    828820     12/8/2021  หญิง  20.0             มหาสารคาม
# 11831    828821     12/8/2021   ชาย  23.0             มหาสารคาม
# 11832    828822     12/8/2021   ชาย  22.0             มหาสารคาม
# 11833    828823     12/8/2021  หญิง  25.0             มหาสารคาม
# 11834    828824     12/8/2021   ชาย  32.0             มหาสารคาม
# ...         ...           ...   ...   ...                   ...
# 203488  1020478     21/8/2021  หญิง  42.0             มหาสารคาม
# 203489  1020479     21/8/2021  หญิง  73.0             มหาสารคาม
# 203490  1020480     21/8/2021   ชาย  38.0             มหาสารคาม
# 203491  1020481     21/8/2021   ชาย  49.0             มหาสารคาม
# 203492  1020482     21/8/2021  หญิง  45.0             มหาสารคาม
#
#                                                     risk
# 11830   การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# 11831        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %%
mydf = df[(df['province_of_isolation'] == 'มหาสารคาม') & (df['announce_date'] == '21/8/2021')]
mydf.groupby('sex').count()['No.']
# Out:
# sex
# ชาย     48
# หญิง    55
# Name: No., dtype: int64

# %% [markdown]
# 5. อยากทราบแนวโน้มของจำนวนผู้ป่วยในแต่ละวัน?

# %%
df.info()  #เช็คข้อมูลยังเป็น ojb อยู่
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213292 entries, 0 to 213291
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   No.                    213292 non-null  int64
#  1   announce_date          213292 non-null  object
#  2   sex                    204047 non-null  object
#  3   age                    198386 non-null  float64
#  4   province_of_isolation  213292 non-null  object
#  5   risk                   213292 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.8+ MB

# %%
df.insert(0, "date", pd.to_datetime(df['announce_date'], format='%d/%m/%Y'), True)
df
# Out:
#              date      No. announce_date   sex   age province_of_isolation  \
# 0      2021-08-12   816990     12/8/2021   ชาย   7.0              เชียงราย
# 1      2021-08-12   816991     12/8/2021   ชาย   1.0              เชียงราย
# 2      2021-08-12   816992     12/8/2021   ชาย  35.0              เชียงราย
# 3      2021-08-12   816993     12/8/2021  หญิง  33.0              เชียงราย
# 4      2021-08-12   816994     12/8/2021  หญิง  14.0              เชียงราย
# ...           ...      ...           ...   ...   ...                   ...
# 213287 2021-08-21  1030277     21/8/2021   ชาย  47.0         กรุงเทพมหานคร
# 213288 2021-08-21  1030278     21/8/2021   ชาย  79.0         กรุงเทพมหานคร
# 213289 2021-08-21  1030279     21/8/2021   ชาย  29.0         กรุงเทพมหานคร
# 213290 2021-08-21  1030280     21/8/2021   ชาย  31.0         กรุงเทพมหานคร
# 213291 2021-08-21  1030281     21/8/2021   ชาย  46.0                ชลบุรี
#
#                                                risk
# ...

# %%
df.groupby('date').count()['No.']
# Out:
# date
# 2021-08-12    22782
# 2021-08-13    23418
# 2021-08-14    22086
# 2021-08-15    21882
# 2021-08-16    21157
# 2021-08-17    20128
# 2021-08-18    20515
# 2021-08-19    20902
# 2021-08-20    19851
# 2021-08-21    20571
# Name: No., dtype: int64

# %%
df.groupby('date').count()['No.'].plot.line(figsize=(10, 5))

# %% [markdown]
# 6. พยากรณ์อัตราผู้ติดเชื้อโควิด?

# %%
pop_df = pd.read_csv('/content/drive/MyDrive/DS/dataCovid/thai_population_63.csv')
pop_df = pop_df[['จังหวัด', 'รวม']] #เลือกคอลัมน์
pop_df
# Out:
#             จังหวัด      รวม
# 0     กรุงเทพมหานคร  5588222
# 1       สมุทรปราการ  1351479
# 2           นนทบุรี  1276745
# 3          ปทุมธานี  1176412
# 4   พระนครศรีอยุธยา   819088
# ..              ...      ...
# 72             ตรัง   640574
# 73           พัทลุง   523077
# 74          ปัตตานี   726015
# 75             ยะลา   538602
# 76         นราธิวาส   804429
#
# [77 rows x 2 columns]

# %%
province_df = df.groupby('province_of_isolation').count()['No.'].reset_index()
province_df
# Out:
#    province_of_isolation    No.
# 0                    กทม    722
# 1                 กระบี่    152
# 2          กรุงเทพมหานคร  44484
# 3              กาญจนบุรี   3016
# 4              กาฬสินธุ์   1295
# ..                   ...    ...
# 73              เพชรบุรี   1025
# 74             เพชรบูรณ์   1456
# 75                   เลย    570
# 76                  แพร่    319
# 77            แม่ฮ่องสอน     37
#
# [78 rows x 2 columns]

# %%
df.insert(2, 'province', df['province_of_isolation'].replace('กทม', 'กรุงเทพมหานคร'), True)
province_df = df.groupby('province').count()['No.'].reset_index()
province_df
# Out:
#          province    No.
# 0          กระบี่    152
# 1   กรุงเทพมหานคร  45206
# 2       กาญจนบุรี   3016
# 3       กาฬสินธุ์   1295
# 4       กำแพงเพชร   1347
# ..            ...    ...
# 72       เพชรบุรี   1025
# 73      เพชรบูรณ์   1456
# 74            เลย    570
# 75           แพร่    319
# 76     แม่ฮ่องสอน     37
#
# [77 rows x 2 columns]

# %%
prov_pop_df = pd.merge(province_df, pop_df, left_on='province', right_on='จังหวัด')
prov_pop_df
# Out:
#          province    No.        จังหวัด      รวม
# 0          กระบี่    152         กระบี่   477770
# 1   กรุงเทพมหานคร  45206  กรุงเทพมหานคร  5588222
# 2       กาญจนบุรี   3016      กาญจนบุรี   891976
# 3       กาฬสินธุ์   1295      กาฬสินธุ์   977175
# 4       กำแพงเพชร   1347      กำแพงเพชร   714118
# ..            ...    ...            ...      ...
# 72       เพชรบุรี   1025       เพชรบุรี   482193
# 73      เพชรบูรณ์   1456      เพชรบูรณ์   981940
# 74            เลย    570            เลย   638736
# 75           แพร่    319           แพร่   437350
# 76     แม่ฮ่องสอน     37     แม่ฮ่องสอน   284549
#
# [77 rows x 4 columns]

# %%
prov_pop_df['rate'] = prov_pop_df['No.'] * 1000000 / prov_pop_df['รวม'] #อัตราผู้ป่วย แสนคน
prov_pop_df
# Out:
#          province    No.        จังหวัด      รวม         rate
# 0          กระบี่    152         กระบี่   477770   318.144714
# 1   กรุงเทพมหานคร  45206  กรุงเทพมหานคร  5588222  8089.513981
# 2       กาญจนบุรี   3016      กาญจนบุรี   891976  3381.256895
# 3       กาฬสินธุ์   1295      กาฬสินธุ์   977175  1325.248804
# 4       กำแพงเพชร   1347      กำแพงเพชร   714118  1886.242890
# ..            ...    ...            ...      ...          ...
# 72       เพชรบุรี   1025       เพชรบุรี   482193  2125.704853
# 73      เพชรบูรณ์   1456      เพชรบูรณ์   981940  1482.778989
# 74            เลย    570            เลย   638736   892.387465
# 75           แพร่    319           แพร่   437350   729.392935
# 76     แม่ฮ่องสอน     37     แม่ฮ่องสอน   284549   130.030329
#
# [77 rows x 5 columns]

# %%
top10_prov_df = prov_pop_df.sort_values('rate').head(10).set_index('จังหวัด')
top10_prov_df
# Out:
#               province  No.      รวม        rate
# จังหวัด
# แม่ฮ่องสอน  แม่ฮ่องสอน   37   284549  130.030329
# เชียงใหม่    เชียงใหม่  510  1784370  285.815162
# ลำปาง            ลำปาง  219   728964  300.426359
# เชียงราย      เชียงราย  412  1295026  318.140331
# กระบี่          กระบี่  152   477770  318.144714
# ลำพูน            ลำพูน  163   402011  405.461542
# พะเยา            พะเยา  225   467356  481.431714
# สตูล              สตูล  159   324098  490.592352
# พังงา            พังงา  147   268229  548.039175
# พัทลุง          พัทลุง  322   523077  615.588145

# %%
top10_prov_df[['No.', 'rate']]
# Out:
#             No.        rate
# จังหวัด
# แม่ฮ่องสอน   37  130.030329
# เชียงใหม่   510  285.815162
# ลำปาง       219  300.426359
# เชียงราย    412  318.140331
# กระบี่      152  318.144714
# ลำพูน       163  405.461542
# พะเยา       225  481.431714
# สตูล        159  490.592352
# พังงา       147  548.039175
# พัทลุง      322  615.588145

# %% [markdown]
# ตั้งค่าฟอนต์ไทยที่แสดงในกราฟ

# %%
import matplotlib as mpl
mpl.__version__
# Out:
# '3.2.2'

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
# !wget -q http://www.arts.chula.ac.th/ling/wp-content/uploads/TH-Sarabun_Chula1.1.zip -O font.zip
# !unzip -qj font.zip TH-Sarabun_Chula1.1/THSarabunChula-Regular.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('THSarabunChula-Regular.ttf')
mpl.rc('font', family='TH Sarabun Chula')

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# แสดงกราฟอัตราการป่วย

# %%
top10_prov_df[['No.', 'rate']].plot.bar(figsize=(20, 10))
